# %%
import pandas as pd
from sklearn.model_selection import KFold, StratifiedKFold
from lofo import LOFOImportance, Dataset, plot_importance

from lightgbm import LGBMClassifier, LGBMRegressor

import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import data
# data_df_1 = pd.read_csv("../../data/training_validation_1.csv")
data_df_2 = pd.read_csv("../../data/training_validation_2.csv")
# train_df = pd.concat([data_df_1, data_df_2], axis=0) # Merge data frames
train_df = data_df_2.filter(regex="vCnt|value")

# del train_df['class']
# del train_df['run']

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17976 entries, 0 to 17975
# Data columns (total 79 columns):
# CpuTemperature_value                           17976 non-null float64
# DurationPickToPick_vCnt                        17976 non-null int64
# DurationPickToPick_value                       17653 non-null float64
# DurationRobotFromFeederToTestBench_vCnt        17976 non-null int64
# DurationRobotFromFeederToTestBench_value       17511 non-null float64
# DurationRobotFromTestBenchToFeeder_vCnt        17976 non-null int64
# DurationRobotFromTestBenchToFeeder_value       16758 non-null float64
# DurationTestBenchClosed_vCnt                   17976 non-null int64
# DurationTestBenchClosed_value                  17528 non-null float64
# EPOSCurrent_vCnt                               17976 non-null int64
# EPOSCurrent_value                              17888 non-null float64
# EPOSPosition_vCnt                              17976 non-null int64
# EPOSPosition_value                             17888 non-null float64
# EPOSVelocity_vCnt                              17976 non-null int64
# EPOSVelocity_value                             17888 non-null float64
# ErrorFrame_vCnt                                17975 non-null float64
# FeederAction1_vCnt                             17976 non-null int64
# FeederAction2_vCnt                             17976 non-null int64
# FeederAction3_vCnt                             17976 non-null int64
# FeederAction4_vCnt                             17976 non-null int64
# FeederBackgroundIlluminationIntensity_vCnt     17976 non-null int64
# FeederBackgroundIlluminationIntensity_value    7529 non-null float64
# FuseCycleDuration_vCnt                         17976 non-null int64
# FuseCycleDuration_value                        17418 non-null float64
# FuseHeatSlope_vCnt                             17976 non-null int64
# FuseHeatSlope_value                            16548 non-null float64
# FuseHeatSlopeNOK_vCnt                          17976 non-null int64
# FuseHeatSlopeNOK_value                         14618 non-null float64
# FuseHeatSlopeOK_vCnt                           17976 non-null int64
# FuseHeatSlopeOK_value                          9012 non-null float64
# FuseIntoFeeder_vCnt                            17976 non-null int64
# FuseOutsideOperationalSpace_vCnt               17976 non-null int64
# FuseOutsideOperationalSpace_value              17662 non-null float64
# FusePicked_vCnt                                17976 non-null int64
# FusePicked_value                               17656 non-null float64
# FuseTestResult_vCnt                            17976 non-null int64
# FuseTestResult_value                           17509 non-null float64
# Humidity_value                                 17973 non-null float64
# IntensityTotalImage_vCnt                       17976 non-null int64
# IntensityTotalImage_value                      7528 non-null float64
# IntensityTotalThermoImage_vCnt                 17976 non-null int64
# IntensityTotalThermoImage_value                16548 non-null float64
# LightBarrieActiveTaskDuration2_vCnt            17976 non-null int64
# LightBarrierActiveTaskDuration1_vCnt           17976 non-null int64
# LightBarrierActiveTaskDuration1_value          17419 non-null float64
# LightBarrierActiveTaskDuration1b_vCnt          17976 non-null int64
# LightBarrierPassiveTaskDuration1_vCnt          17976 non-null int64
# LightBarrierPassiveTaskDuration1_value         17972 non-null float64
# LightBarrierPassiveTaskDuration1b_vCnt         17976 non-null int64
# LightBarrierPassiveTaskDuration2_vCnt          17976 non-null int64
# LightBarrierTaskDuration_vCnt                  17976 non-null int64
# NumberEmptyFeeder_vCnt                         17976 non-null int64
# NumberFuseDetected_vCnt                        17976 non-null int64
# NumberFuseDetected_value                       6207 non-null float64
# NumberFuseEstimated_vCnt                       17976 non-null int64
# NumberFuseEstimated_value                      7537 non-null float64
# Pressure_vCnt                                  17976 non-null int64
# Pressure_value                                 17966 non-null float64
# ProcessCpuLoadNormalized_value                 17976 non-null float64
# ProcessMemoryConsumption_value                 17976 non-null float64
# SharpnessImage_vCnt                            17976 non-null int64
# SharpnessImage_value                           7527 non-null float64
# SmartMotorPositionError_vCnt                   17976 non-null int64
# SmartMotorPositionError_value                  17971 non-null float64
# SmartMotorSpeed_vCnt                           17976 non-null int64
# SmartMotorSpeed_value                          17971 non-null float64
# Temperature_value                              17973 non-null float64
# TemperatureThermoCam_vCnt                      17976 non-null int64
# TemperatureThermoCam_value                     16548 non-null float64
# TotalCpuLoadNormalized_value                   17976 non-null float64
# TotalMemoryConsumption_value                   17976 non-null float64
# Vacuum_vCnt                                    17976 non-null int64
# Vacuum_value                                   17888 non-null float64
# VacuumFusePicked_vCnt                          17976 non-null int64
# VacuumFusePicked_value                         17622 non-null float64
# VacuumValveClosed_vCnt                         17976 non-null int64
# VacuumValveClosed_value                        17878 non-null float64
# ValidFrame_vCnt                                17975 non-null float64
# ValidFrameOptrisPIIRCamera_vCnt                17975 non-null float64
# dtypes: float64(39), int64(40)
# memory usage: 10.8 MB

# %%
fig = plt.figure(figsize=(20,15), dpi=75)
sns.heatmap(train_df.corr(),annot=False)
