# %%
import numpy as np
from numpy import nan
import pandas as pd

import pickle
import collections
from collections import defaultdict 

from matplotlib import pyplot as plt
from os import listdir
from os.path import isfile, join

import re

# %%
# Convert field names to dict for easy access.
# Can be hard coded 
# 
fields_path = '../../input/training_validation_2/fields.csv'  
fields_df = pd.read_csv(fields_path)
fields_df.columns = ['name', 'f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6']

fields_dict = {}

for idx in range(fields_df.shape[0]):
    name = fields_df.loc[idx, 'name']

    _fields = []
    
    for f in fields_df.columns[1:]:
        if not (str(fields_df.loc[idx, f]) == 'nan'):
            _fields.append(name + "_" + str(fields_df.loc[idx, f]))
    
    fields_dict[idx] = {'name': fields_df.loc[idx, 'name'] , 'fields': _fields}

fields_dict
# Out:
# {0: {'name': 'CpuTemperature',
#   'fields': ['CpuTemperature_vMax',
#    'CpuTemperature_vMin',
#    'CpuTemperature_vStd',
#    'CpuTemperature_value']},
#  1: {'name': 'DurationPickToPick',
#   'fields': ['DurationPickToPick_vCnt',
#    'DurationPickToPick_vFreq',
#    'DurationPickToPick_vMax',
#    'DurationPickToPick_vMin',
#    'DurationPickToPick_vStd',
#    'DurationPickToPick_vTrend',
#    'DurationPickToPick_value']},
#  2: {'name': 'DurationRobotFromFeederToTestBench',
#   'fields': ['DurationRobotFromFeederToTestBench_vCnt',
#    'DurationRobotFromFeederToTestBench_vFreq',
#    'DurationRobotFromFeederToTestBench_vMax',
#    'DurationRobotFromFeederToTestBench_vMin',
#    'DurationRobotFromFeederToTestBench_vStd',
#    'DurationRobotFromFeederToTestBench_vTrend',
#    'DurationRobotFromFeederToTestBench_value']},
#  3: {'name': 'DurationRobotFromTestBenchToFeeder',
#   'fields': ['DurationRobotFromTestBenchToFeeder_vCnt',
#    'DurationRobotFromTestBenchToFeeder_vFreq',
#    'DurationRobotFromTestBenchToFeeder_vMax',
#    'DurationRobotFromTestBenchToFeeder_vMin',
#    'DurationRobotFromTestBenchToFeeder_vStd',
#    'DurationRobotFromTestBenchToFeeder_vTrend',
#    'DurationRobotFromTestBenchToFeeder_value']},
#  4: {'name': 'DurationTestBenchClosed',
#   'fields': ['DurationTestBenchClosed_vCnt',
#    'DurationTestBenchClosed_vFreq',
#    'DurationTestBenchClosed_vMax',
#    'DurationTestBenchClosed_vMin',
#    'DurationTestBenchClosed_vStd',
#    'DurationTestBenchClosed_vTrend',
#    'DurationTestBenchClosed_value']},
#  5: {'name': 'EPOSCurrent',
#   'fields': ['EPOSCurrent_vCnt',
#    'EPOSCurrent_vFreq',
#    'EPOSCurrent_vMax',
#    'EPOSCurrent_vMin',
#    'EPOSCurrent_vStd',
#    'EPOSCurrent_vTrend',
#    'EPOSCurrent_value']},
#  6: {'name': 'EPOSPosition',
#   'fields': ['EPOSPosition_vCnt',
#    'EPOSPosition_vFreq',
#    'EPOSPosition_vMax',
#    'EPOSPosition_vMin',
#    'EPOSPosition_vStd',
#    'EPOSPosition_vTrend',
#    'EPOSPosition_value']},
#  7: {'name': 'EPOSVelocity',
#   'fields': ['EPOSVelocity_vCnt',
#    'EPOSVelocity_vFreq',
#    'EPOSVelocity_vMax',
#    'EPOSVelocity_vMin',
#    'EPOSVelocity_vStd',
#    'EPOSVelocity_vTrend',
#    'EPOSVelocity_value']},
#  8: {'name': 'ErrorFrame', 'fields': ['ErrorFrame_vCnt', 'ErrorFrame_vFreq']},
#  9: {'name': 'FeederAction1', 'fields': ['FeederAction1_vCnt']},
#  10: {'name': 'FeederAction2', 'fields': ['FeederAction2_vCnt']},
#  11: {'name': 'FeederAction3', 'fields': ['FeederAction3_vCnt']},
#  12: {'name': 'FeederAction4', 'fields': ['FeederAction4_vCnt']},
#  13: {'name': 'FeederBackgroundIlluminationIntensity',
#   'fields': ['FeederBackgroundIlluminationIntensity_vCnt',
#    'FeederBackgroundIlluminationIntensity_vFreq',
#    'FeederBackgroundIlluminationIntensity_vMax',
#    'FeederBackgroundIlluminationIntensity_vMin',
#    'FeederBackgroundIlluminationIntensity_vStd',
#    'FeederBackgroundIlluminationIntensity_vTrend',
#    'FeederBackgroundIlluminationIntensity_value']},
#  14: {'name': 'FuseCycleDuration',
#   'fields': ['FuseCycleDuration_vCnt',
#    'FuseCycleDuration_vFreq',
#    'FuseCycleDuration_vMax',
#    'FuseCycleDuration_vMin',
#    'FuseCycleDuration_vStd',
#    'FuseCycleDuration_vTrend',
#    'FuseCycleDuration_value']},
#  15: {'name': 'FuseHeatSlope',
#   'fields': ['FuseHeatSlope_vCnt',
#    'FuseHeatSlope_vFreq',
#    'FuseHeatSlope_vMax',
#    'FuseHeatSlope_vMin',
#    'FuseHeatSlope_vStd',
#    'FuseHeatSlope_vTrend',
#    'FuseHeatSlope_value']},
#  16: {'name': 'FuseHeatSlopeNOK',
#   'fields': ['FuseHeatSlopeNOK_vCnt',
#    'FuseHeatSlopeNOK_vFreq',
#    'FuseHeatSlopeNOK_vMax',
#    'FuseHeatSlopeNOK_vMin',
#    'FuseHeatSlopeNOK_vStd',
#    'FuseHeatSlopeNOK_vTrend',
#    'FuseHeatSlopeNOK_value']},
#  17: {'name': 'FuseHeatSlopeOK',
#   'fields': ['FuseHeatSlopeOK_vCnt',
#    'FuseHeatSlopeOK_vFreq',
#    'FuseHeatSlopeOK_vMax',
#    'FuseHeatSlopeOK_vMin',
#    'FuseHeatSlopeOK_vStd',
#    'FuseHeatSlopeOK_vTrend',
#    'FuseHeatSlopeOK_value']},
#  18: {'name': 'FuseIntoFeeder', 'fields': ['FuseIntoFeeder_vCnt']},
#  19: {'name': 'FuseOutsideOperationalSpace',
#   'fields': ['FuseOutsideOperationalSpace_vCnt',
#    'FuseOutsideOperationalSpace_vFreq',
#    'FuseOutsideOperationalSpace_vMax',
#    'FuseOutsideOperationalSpace_vMin',
#    'FuseOutsideOperationalSpace_vStd',
#    'FuseOutsideOperationalSpace_vTrend',
#    'FuseOutsideOperationalSpace_value']},
#  20: {'name': 'FusePicked',
#   'fields': ['FusePicked_vCnt',
#    'FusePicked_vFreq',
#    'FusePicked_vMax',
#    'FusePicked_vMin',
#    'FusePicked_vStd',
#    'FusePicked_vTrend',
#    'FusePicked_value']},
#  21: {'name': 'FuseTestResult',
#   'fields': ['FuseTestResult_vCnt',
#    'FuseTestResult_vFreq',
#    'FuseTestResult_vMax',
#    'FuseTestResult_vMin',
#    'FuseTestResult_vStd',
#    'FuseTestResult_vTrend',
#    'FuseTestResult_value']},
#  22: {'name': 'Humidity', 'fields': ['Humidity_value']},
#  23: {'name': 'IntensityTotalImage',
#   'fields': ['IntensityTotalImage_vCnt',
#    'IntensityTotalImage_vFreq',
#    'IntensityTotalImage_vMax',
#    'IntensityTotalImage_vMin',
#    'IntensityTotalImage_vStd',
#    'IntensityTotalImage_vTrend',
#    'IntensityTotalImage_value']},
#  24: {'name': 'IntensityTotalThermoImage',
#   'fields': ['IntensityTotalThermoImage_vCnt',
#    'IntensityTotalThermoImage_vFreq',
#    'IntensityTotalThermoImage_vMax',
#    'IntensityTotalThermoImage_vMin',
#    'IntensityTotalThermoImage_vStd',
#    'IntensityTotalThermoImage_vTrend',
#    'IntensityTotalThermoImage_value']},
#  25: {'name': 'LightBarrieActiveTaskDuration2',
#   'fields': ['LightBarrieActiveTaskDuration2_vCnt',
#    'LightBarrieActiveTaskDuration2_vFreq']},
#  26: {'name': 'LightBarrierActiveTaskDuration1',
#   'fields': ['LightBarrierActiveTaskDuration1_vCnt',
#    'LightBarrierActiveTaskDuration1_vFreq',
#    'LightBarrierActiveTaskDuration1_vMax',
#    'LightBarrierActiveTaskDuration1_vMin',
#    'LightBarrierActiveTaskDuration1_vStd',
#    'LightBarrierActiveTaskDuration1_vTrend',
#    'LightBarrierActiveTaskDuration1_value']},
#  27: {'name': 'LightBarrierActiveTaskDuration1b',
#   'fields': ['LightBarrierActiveTaskDuration1b_vCnt',
#    'LightBarrierActiveTaskDuration1b_vFreq']},
#  28: {'name': 'LightBarrierPassiveTaskDuration1',
#   'fields': ['LightBarrierPassiveTaskDuration1_vCnt',
#    'LightBarrierPassiveTaskDuration1_vFreq',
#    'LightBarrierPassiveTaskDuration1_vMax',
#    'LightBarrierPassiveTaskDuration1_vMin',
#    'LightBarrierPassiveTaskDuration1_vStd',
#    'LightBarrierPassiveTaskDuration1_vTrend',
#    'LightBarrierPassiveTaskDuration1_value']},
#  29: {'name': 'LightBarrierPassiveTaskDuration1b',
#   'fields': ['LightBarrierPassiveTaskDuration1b_vCnt',
#    'LightBarrierPassiveTaskDuration1b_vFreq']},
#  30: {'name': 'LightBarrierPassiveTaskDuration2',
#   'fields': ['LightBarrierPassiveTaskDuration2_vCnt',
#    'LightBarrierPassiveTaskDuration2_vFreq']},
#  31: {'name': 'LightBarrierTaskDuration',
#   'fields': ['LightBarrierTaskDuration_vCnt',
#    'LightBarrierTaskDuration_vFreq']},
#  32: {'name': 'NumberEmptyFeeder', 'fields': ['NumberEmptyFeeder_vCnt']},
#  33: {'name': 'NumberFuseDetected',
#   'fields': ['NumberFuseDetected_vCnt',
#    'NumberFuseDetected_vFreq',
#    'NumberFuseDetected_vMax',
#    'NumberFuseDetected_vMin',
#    'NumberFuseDetected_vStd',
#    'NumberFuseDetected_vTrend',
#    'NumberFuseDetected_value']},
#  34: {'name': 'NumberFuseEstimated',
#   'fields': ['NumberFuseEstimated_vCnt',
#    'NumberFuseEstimated_vFreq',
#    'NumberFuseEstimated_vMax',
#    'NumberFuseEstimated_vMin',
#    'NumberFuseEstimated_vStd',
#    'NumberFuseEstimated_vTrend',
#    'NumberFuseEstimated_value']},
#  35: {'name': 'Pressure',
#   'fields': ['Pressure_vCnt',
#    'Pressure_vFreq',
#    'Pressure_vMax',
#    'Pressure_vMin',
#    'Pressure_vStd',
#    'Pressure_vTrend',
#    'Pressure_value']},
#  36: {'name': 'ProcessCpuLoadNormalized',
#   'fields': ['ProcessCpuLoadNormalized_vMax',
#    'ProcessCpuLoadNormalized_vMin',
#    'ProcessCpuLoadNormalized_vStd',
#    'ProcessCpuLoadNormalized_value']},
#  37: {'name': 'ProcessMemoryConsumption',
#   'fields': ['ProcessMemoryConsumption_vMax',
#    'ProcessMemoryConsumption_vMin',
#    'ProcessMemoryConsumption_vStd',
#    'ProcessMemoryConsumption_value']},
#  38: {'name': 'SharpnessImage',
#   'fields': ['SharpnessImage_vCnt',
#    'SharpnessImage_vFreq',
#    'SharpnessImage_vMax',
#    'SharpnessImage_vMin',
#    'SharpnessImage_vStd',
#    'SharpnessImage_vTrend',
#    'SharpnessImage_value']},
#  39: {'name': 'SmartMotorPositionError',
#   'fields': ['SmartMotorPositionError_vCnt',
#    'SmartMotorPositionError_vFreq',
#    'SmartMotorPositionError_vMax',
#    'SmartMotorPositionError_vMin',
#    'SmartMotorPositionError_vStd',
#    'SmartMotorPositionError_vTrend',
#    'SmartMotorPositionError_value']},
#  40: {'name': 'SmartMotorSpeed',
#   'fields': ['SmartMotorSpeed_vCnt',
#    'SmartMotorSpeed_vFreq',
#    'SmartMotorSpeed_vMax',
#    'SmartMotorSpeed_vMin',
#    'SmartMotorSpeed_vStd',
#    'SmartMotorSpeed_vTrend',
#    'SmartMotorSpeed_value']},
#  41: {'name': 'Temperature', 'fields': ['Temperature_value']},
#  42: {'name': 'TemperatureThermoCam',
#   'fields': ['TemperatureThermoCam_vCnt',
#    'TemperatureThermoCam_vFreq',
#    'TemperatureThermoCam_vMax',
#    'TemperatureThermoCam_vMin',
#    'TemperatureThermoCam_vStd',
#    'TemperatureThermoCam_vTrend',
#    'TemperatureThermoCam_value']},
#  43: {'name': 'TotalCpuLoadNormalized',
#   'fields': ['TotalCpuLoadNormalized_vMax',
#    'TotalCpuLoadNormalized_vMin',
#    'TotalCpuLoadNormalized_vStd',
#    'TotalCpuLoadNormalized_value']},
#  44: {'name': 'TotalMemoryConsumption',
#   'fields': ['TotalMemoryConsumption_vMax',
#    'TotalMemoryConsumption_vMin',
#    'TotalMemoryConsumption_vStd',
#    'TotalMemoryConsumption_value']},
#  45: {'name': 'Vacuum',
#   'fields': ['Vacuum_vCnt',
#    'Vacuum_vFreq',
#    'Vacuum_vMax',
#    'Vacuum_vMin',
#    'Vacuum_vStd',
#    'Vacuum_vTrend',
#    'Vacuum_value']},
#  46: {'name': 'VacuumFusePicked',
#   'fields': ['VacuumFusePicked_vCnt',
#    'VacuumFusePicked_vFreq',
#    'VacuumFusePicked_vMax',
#    'VacuumFusePicked_vMin',
#    'VacuumFusePicked_vStd',
#    'VacuumFusePicked_vTrend',
#    'VacuumFusePicked_value']},
#  47: {'name': 'VacuumValveClosed',
#   'fields': ['VacuumValveClosed_vCnt',
#    'VacuumValveClosed_vFreq',
#    'VacuumValveClosed_vMax',
#    'VacuumValveClosed_vMin',
#    'VacuumValveClosed_vStd',
#    'VacuumValveClosed_vTrend',
#    'VacuumValveClosed_value']},
#  48: {'name': 'ValidFrame', 'fields': ['ValidFrame_vCnt', 'ValidFrame_vFreq']},
#  49: {'name': 'ValidFrameOptrisPIIRCamera',
#   'fields': ['ValidFrameOptrisPIIRCamera_vCnt',
#    'ValidFrameOptrisPIIRCamera_vFreq']}}

# %%
# Get class id and run id from filename
def parse_class_name(fname):
    p = re.compile("^class[^\d]*(\d+)_(\d+).*.csv")
    m = p.match(fname)
    
    return m.groups()

# %%
# Load one data file and return in a data frame
def load_data_file(path, fname):
    fullpath = join(path,fname)
    df = pd.read_csv(fullpath)
    df.columns = ['name', 'data']
    
    dfx = []
    
    for f in fields_dict:
        name = fields_dict[f]['name']
        fields = fields_dict[f]['fields']
        
        data = eval(df.loc[f,'data']) # convert data to array
        
        new_df = pd.DataFrame(data)
        if (f==33) and (new_df.shape[1] == 6): # NumberFuseDetected has a special case!
            new_df[6] = new_df[5]
            new_df[5] = np.NaN
            

        new_df.columns = fields_dict[f]['fields']
        
        dfx.append(new_df)
        
    merged_df = pd.concat(dfx, axis=1) # Merge columns
    
    c, r = parse_class_name(fname) # Get class id and run id

    # Add class labels and run id
    merged_df['class'] = int(c)
    merged_df['run'] = int(r)

    return merged_df

# %%
# Load data files from a directory and return merged data frame
def load_data_files(path):
    
    print ("In", path)
    files = [] 
    for f in listdir(path):
        if (isfile(join(path, f)) and (f.startswith("class"))):
            files.append(f)
    
    data_df_list = []
    for fname in files:
        print ("Loading:", fname)
        
        df = load_data_file(path, fname)
        
        data_df_list.append(df)

    data_df = pd.concat(data_df_list, axis=0) # Merge data frames
    
    return data_df

# %%
# %%time
data_df_1 = load_data_files("../../input/training_validation_1/")
data_df_2 = load_data_files("../../input/training_validation_2/")
data_df_3 = load_data_files("../../input/ModelRefinement/")
# Out:
# In ../../input/training_validation_1/
# Loading: class_ 0_36_data.csv
# Loading: class_ 0_18_data.csv
# Loading: class_ 0_76_data.csv
# Loading: class_ 0_5_data.csv
# Loading: class_ 0_45_data.csv
# Loading: class_ 0_57_data.csv
# Loading: class_ 0_47_data.csv
# Loading: class_ 0_43_data.csv
# Loading: class_ 0_8_data.csv
# Loading: class_ 0_55_data.csv
# Loading: class_ 0_9_data.csv
# Loading: class_ 0_19_data.csv
# Loading: class_ 0_31_data.csv
# Loading: class_ 0_35_data.csv
# Loading: class_ 0_74_data.csv
# Loading: class_ 0_20_data.csv
# Loading: class_ 0_27_data.csv
# Loading: class_ 0_1_data.csv
# Loading: class_ 0_32_data.csv
# Loading: class_ 0_11_data.csv
# Loading: class_ 0_67_data.csv
# Loading: class_ 0_56_data.csv
# Loading: class_ 0_0_data.csv
# Loading: class_ 0_60_data.csv
# Loading: class_ 0_29_data.csv
# Loading: class_ 0_41_data.csv
# Loading: class_ 0_25_data.csv
# Loading: class_ 0_66_data.csv
# Loading: class_ 0_23_data.csv
# Loading: class_ 0_6_data.csv
# Loading: class_ 0_75_data.csv
# Loading: class_ 0_17_data.csv
# Loading: class_ 0_54_data.csv
# Loading: class_ 0_7_data.csv
# Loading: class_ 0_80_data.csv
# Loading: class_ 0_77_data.csv
# Loading: class_ 0_38_data.csv
# Loading: class_ 0_53_data.csv
# Loading: class_ 0_46_data.csv
# Loading: class_ 0_37_data.csv
# In ../../input/training_validation_2/
# Loading: class_ 3_0_data.csv
# Loading: class_ 0_93_data.csv
# Loading: class_ 3_3_data.csv
# Loading: class_ 7_3_data.csv
# Loading: class_ 2_2_data.csv
# Loading: class_ 5_3_data.csv
# Loading: class_ 0_88_data.csv
# Loading: class_ 7_5_data.csv
# Loading: class_ 5_4_data.csv
# Loading: class_ 9_2_data.csv
# Loading: class_ 0_90_data.csv
# Loading: class_ 9_5_data.csv
# Loading: class_ 0_86_data.csv
# Loading: class_ 0_101_data.csv
# Loading: class_ 7_2_data.csv
# Loading: class_ 0_97_data.csv
# Loading: class_ 9_3_data.csv
# Loading: class_ 0_81_data.csv
# Loading: class_ 3_2_data.csv
# Loading: class_ 0_83_data.csv
# Loading: class_ 0_91_data.csv
# Loading: class_ 3_4_data.csv
# Loading: class_ 0_96_data.csv
# Loading: class_ 5_0_data.csv
# Loading: class_ 2_4_data.csv
# Loading: class_ 2_0_data.csv
# Loading: class_ 7_0_data.csv
# Loading: class_ 5_2_data.csv
# Loading: class_ 9_1_data.csv
# Loading: class_ 2_3_data.csv
# In ../../input/ModelRefinement/
# Loading: class_12_1_data.csv
# Loading: class_ 0_10_data.csv
# Loading: class_ 0_103_data.csv
# Loading: class_ 0_89_data.csv
# Loading: class_ 4_4_data.csv
# Loading: class_ 0_100_data.csv
# Loading: class_ 0_51_data.csv
# Loading: class_12_0_data.csv

# %%
data_df_1.shape, data_df_2.shape, data_df_3.shape

# %%
# Uncomment to store data frames

data_df_1.to_csv("../../data/training_validation_1.csv", index=False)
data_df_2.to_csv("../../data/training_validation_2.csv", index=False)
data_df_3.to_csv("../../data/model_refinement.csv", index=False)
